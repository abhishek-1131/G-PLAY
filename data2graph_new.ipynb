# %%
import torch
torch.cuda.is_available()
print(torch.zeros(1).cuda())
# Out:
# tensor([0.], device='cuda:0')

# %%
import torch
import torch_geometric
import torch_geometric.nn as pyg_nn
from torch_sparse import SparseTensor, matmul
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv
print(torch_geometric.__version__)

import torch_scatter
import torch.nn as nn
import torch.nn.functional as F

import torch_geometric.utils as pyg_utils

from torch import Tensor
from typing import Union, Tuple, Optional
from torch_geometric.typing import (OptPairTensor, Adj, Size, NoneType, OptTensor)

from torch.nn import Parameter, Linear
from torch_sparse import SparseTensor, set_diag
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.utils import remove_self_loops, add_self_loops, softmax

import networkx as nx
from deepsnap.hetero_graph import HeteroGraph
import copy
from copy import deepcopy
import pickle

import deepsnap
from deepsnap.graph import Graph
from deepsnap.batch import Batch
from deepsnap.dataset import GraphDataset
from deepsnap.hetero_gnn import forward_op
from deepsnap.hetero_graph import HeteroGraph
from sklearn.metrics import f1_score, roc_auc_score

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import json
from pathlib import Path as Data_Path
from os import listdir
from os.path import isfile, join
from itertools import combinations
from tqdm.notebook import tqdm
# Out:
# 2.1.0

# %%
import graph_tool.all as gt
print("graph-tool version: {}".format(gt.__version__.split(' ')[0]))
# Out:
# graph-tool version: 2.46

# %%
f = open('./CMPT-733-Project/mpd.slice.0-999.json')
data = json.load(f)
print(type(data))
# Out:
# <class 'dict'>

# %%
def playlists2graph(g, data_json):
    #add playlist nodes
    playlist_attrs = []
    for playlist in data_json['playlists']:
        playlist_attrs.append({'name': playlist['name'], 'type': 'playlist'})
 
    g.vp['name'] = g.new_vertex_property('string')
    g.vp['type'] = g.new_vertex_property('string')
    for node_attrs in playlist_attrs:
        v = g.add_vertex()
        for key, value in node_attrs.items():
            g.vp[key][v] = value
            
def tracks2graph(g, data_json):
    #add track nodes
    track_attrs = []
    for playlist in data_json['playlists']:
        tracks_list = playlist['tracks']
        for track in tracks_list:
            track_attrs.append({'uri': track['track_uri'], 'name': track['track_name'], 'type': 'track'})

    g.vp['uri'] = g.new_vertex_property('string')
    g.vp['name'] = g.new_vertex_property('string')
    g.vp['type'] = g.new_vertex_property('string')
    for node_attrs in track_attrs:
        v = g.add_vertex()
        for key, value in node_attrs.items():
            g.vp[key][v] = value
        
# def artists2graph(g, tracks_list):
#     #add artist nodes
#     artist_attrs = []
#     for track in tracks_list:
#         artist_attrs.append({'uri': track['artist_uri'], 'name': track['artist_name'], 'type': 'artist'})

#     g.vp['uri'] = g.new_vertex_property('string')
#     g.vp['name'] = g.new_vertex_property('string')
#     g.vp['type'] = g.new_vertex_property('string')
#     for i, node_attrs in enumerate(artist_attrs):
#         v = g.add_vertex()
#         for key, value in node_attrs.items():
#             g.vp[key][v] = value

# def append_graphs(g1, g2):
#     # Get the last vertex index from g1
#     last_vindex = g1.num_vertices() - 1

#     # Get vertex properties from g1
#     vp1 = {key: g1.vp[key] for key in g1.vertex_properties.keys()}

#     # Add vertex properties to g2
#     for key, value in vp1.items():
#         g2.vp[key] = g2.new_vertex_property(value.value_type())

#     # Append vertices from g1 to g2 with new index
#     for v in g1.vertices():
#         new_v = g2.add_vertex()
#         for key, value in vp1.items():
#             g2.vp[key][new_v] = value[v]

# %%
G = gt.Graph()
playlists2graph(G, data)

# for i in range(len(data['playlists'])):
tracks2graph(G, data)
    

# # for i in range(len(data['playlists'])):
# g_temp = gt.Graph()
# artists2graph(g_temp, data['playlists'][0]['tracks'])

# append_graphs(g_temp, G)

# %%
G.num_vertices()
# Out:
# 68503

# %%
for v in G.vertices():
    print("Node", int(v), "has attrs:")
    for prop in G.vertex_properties:
        print("  -", prop, ":", G.vertex_properties[prop][v])
# Out:
# Node 0 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 1 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 2 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 3 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 4 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 5 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 6 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 7 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 8 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 9 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 10 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 11 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 12 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 13 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 14 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 15 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 16 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 17 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 18 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 19 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 20 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 21 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 22 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 23 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 24 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 25 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 26 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 27 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 28 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 29 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 30 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 31 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 32 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 33 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 34 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 35 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 36 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 37 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 38 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 39 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 40 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 41 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 42 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 43 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 44 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 45 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 46 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 47 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 48 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 49 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 50 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 51 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 52 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 53 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 54 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 55 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 56 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 57 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 58 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 59 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 60 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 61 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 62 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 63 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 64 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 65 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 66 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 67 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 68 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 69 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 70 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 71 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 72 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 73 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 74 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 75 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 76 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 77 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 78 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 79 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 80 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 81 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 82 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 83 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 84 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 85 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 86 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 87 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 88 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 89 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 90 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 91 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 92 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 93 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 94 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 95 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 96 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 97 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 98 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 99 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 100 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 101 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 102 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 103 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 104 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 105 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 106 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 107 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 108 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 109 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 110 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 111 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 112 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 113 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 114 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 115 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 116 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 117 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 118 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 119 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 120 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 121 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 122 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 123 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 124 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 125 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 126 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 127 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 128 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 129 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 130 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 131 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 132 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 133 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 134 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 135 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 136 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 137 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 138 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 139 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 140 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 141 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 142 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 143 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 144 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 145 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 146 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 147 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 148 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 149 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 150 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 151 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 152 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 153 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 154 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 155 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 156 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 157 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 158 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 159 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 160 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 161 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 162 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 163 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 164 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 165 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 166 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 167 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 168 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 169 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 170 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 171 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 172 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 173 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 174 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 175 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 176 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 177 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 178 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 179 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 180 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 181 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 182 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 183 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 184 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 185 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 186 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 187 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 188 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 189 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 190 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 191 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 192 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 193 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 194 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 195 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 196 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 197 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 198 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 199 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 200 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 201 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 202 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 203 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 204 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 205 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 206 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 207 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 208 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 209 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 210 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 211 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 212 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 213 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 214 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 215 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 216 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 217 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 218 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 219 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 220 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 221 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 222 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 223 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 224 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 225 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 226 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 227 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 228 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 229 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 230 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 231 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 232 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 233 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 234 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 235 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 236 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 237 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 238 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 239 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 240 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 241 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 242 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 243 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 244 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 245 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 246 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 247 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 248 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 249 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 250 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 251 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 252 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 253 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 254 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 255 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 256 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 257 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 258 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 259 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 260 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 261 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 262 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 263 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 264 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 265 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 266 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 267 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 268 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 269 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 270 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 271 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 272 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 273 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 274 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 275 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 276 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 277 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 278 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 279 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 280 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 281 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 282 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 283 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 284 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 285 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 286 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 287 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 288 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 289 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 290 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 291 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 292 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 293 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 294 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 295 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 296 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 297 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 298 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 299 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 300 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 301 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 302 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 303 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 304 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 305 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 306 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 307 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 308 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 309 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 310 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 311 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 312 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 313 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 314 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 315 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 316 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 317 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 318 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 319 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 320 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 321 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 322 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 323 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 324 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 325 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 326 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 327 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 328 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 329 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 330 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 331 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 332 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 333 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 334 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 335 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 336 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 337 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 338 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 339 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 340 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 341 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 342 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 343 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 344 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 345 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 346 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 347 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 348 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 349 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 350 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 351 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 352 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 353 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 354 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 355 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 356 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 357 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 358 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 359 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 360 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 361 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 362 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 363 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 364 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 365 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 366 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 367 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 368 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 369 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 370 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 371 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 372 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 373 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 374 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 375 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 376 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 377 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 378 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 379 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 380 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 381 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 382 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 383 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 384 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 385 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 386 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 387 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 388 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 389 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 390 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 391 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 392 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 393 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 394 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 395 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 396 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 397 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 398 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 399 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 400 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 401 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 402 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 403 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 404 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 405 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 406 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 407 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 408 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 409 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 410 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 411 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 412 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 413 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 414 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 415 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 416 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 417 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 418 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 419 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 420 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 421 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 422 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 423 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 424 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 425 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 426 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 427 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 428 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 429 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 430 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 431 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 432 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 433 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 434 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 435 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 436 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 437 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 438 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 439 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 440 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 441 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 442 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 443 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 444 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 445 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 446 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 447 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 448 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 449 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 450 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 451 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 452 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 453 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 454 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 455 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 456 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 457 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 458 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 459 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 460 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 461 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 462 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 463 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 464 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 465 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 466 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 467 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 468 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 469 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 470 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 471 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 472 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 473 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 474 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 475 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 476 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 477 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 478 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 479 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 480 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 481 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 482 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 483 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 484 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 485 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 486 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 487 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 488 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 489 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 490 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 491 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 492 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 493 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 494 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 495 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 496 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 497 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 498 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 499 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 500 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 501 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 502 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 503 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 504 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 505 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 506 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 507 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 508 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 509 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 510 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 511 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 512 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 513 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 514 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 515 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 516 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 517 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 518 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 519 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 520 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 521 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 522 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 523 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 524 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 525 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 526 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 527 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 528 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 529 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 530 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 531 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 532 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 533 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 534 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 535 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 536 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 537 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 538 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 539 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 540 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 541 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 542 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 543 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 544 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 545 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 546 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 547 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 548 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 549 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 550 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 551 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 552 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 553 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 554 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 555 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 556 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 557 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 558 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 559 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 560 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 561 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 562 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 563 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 564 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 565 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 566 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 567 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 568 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 569 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 570 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 571 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 572 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 573 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 574 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 575 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 576 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 577 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 578 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 579 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 580 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 581 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 582 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 583 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 584 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 585 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 586 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 587 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 588 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 589 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 590 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 591 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 592 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 593 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 594 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 595 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 596 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 597 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 598 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 599 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 600 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 601 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 602 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 603 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 604 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 605 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 606 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 607 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 608 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 609 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 610 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 611 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 612 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 613 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 614 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 615 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 616 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 617 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 618 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 619 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 620 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 621 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 622 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 623 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 624 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 625 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 626 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 627 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 628 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 629 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 630 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 631 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 632 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 633 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 634 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 635 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 636 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 637 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 638 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 639 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 640 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 641 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 642 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 643 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 644 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 645 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 646 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 647 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 648 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 649 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 650 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 651 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 652 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 653 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 654 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 655 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 656 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 657 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 658 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 659 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 660 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 661 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 662 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 663 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 664 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 665 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 666 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 667 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 668 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 669 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 670 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 671 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 672 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 673 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 674 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 675 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 676 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 677 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 678 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 679 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 680 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 681 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 682 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 683 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 684 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 685 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 686 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 687 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 688 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 689 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 690 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 691 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 692 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 693 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 694 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 695 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 696 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 697 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 698 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 699 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 700 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 701 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 702 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 703 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 704 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 705 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 706 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 707 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 708 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 709 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 710 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 711 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 712 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 713 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 714 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 715 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 716 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 717 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 718 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 719 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 720 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 721 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 722 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 723 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 724 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 725 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 726 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 727 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 728 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 729 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 730 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 731 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 732 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 733 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 734 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 735 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 736 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 737 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 738 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 739 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 740 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 741 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 742 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 743 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 744 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 745 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 746 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 747 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 748 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 749 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 750 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 751 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 752 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 753 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 754 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 755 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 756 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 757 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 758 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 759 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 760 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 761 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 762 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 763 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 764 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 765 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 766 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 767 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 768 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 769 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 770 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 771 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 772 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 773 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 774 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 775 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 776 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 777 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 778 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 779 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 780 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 781 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 782 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 783 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 784 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 785 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 786 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 787 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 788 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 789 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 790 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 791 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 792 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 793 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 794 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 795 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 796 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 797 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 798 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 799 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 800 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 801 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 802 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 803 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 804 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 805 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 806 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 807 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 808 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 809 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 810 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 811 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 812 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 813 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 814 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 815 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 816 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 817 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 818 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 819 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 820 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 821 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 822 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 823 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 824 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 825 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 826 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 827 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 828 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 829 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 830 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 831 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 832 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 833 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 834 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 835 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 836 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 837 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 838 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 839 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 840 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 841 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 842 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 843 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 844 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 845 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 846 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 847 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 848 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 849 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 850 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 851 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 852 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 853 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 854 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 855 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 856 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 857 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 858 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 859 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 860 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 861 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 862 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 863 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 864 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 865 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 866 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 867 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 868 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 869 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 870 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 871 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 872 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 873 has attrs:
#   - name :
#   - type :
#   - uri :
# Node 874 has attrs:
#   - name :
# ...
# Node 22537 has attrs:
#   - name : What's Luv? (feat. Ja-Rule & Ashanti) - Featuring Ja-Rule & Ashanti Explicit Album Version
#   - type : track
#   - uri : spotify:track:2mKouqwAIdQnMP43zxR89r
# Node 22538 has attrs:
#   - name : In Da Club
#   - type : track
#   - uri : spotify:track:7iL6o9tox1zgHpKUfh9vuC
# Node 22539 has attrs:
#   - name : Gasolina Budda Remix - Remix
#   - type : track
#   - uri : spotify:track:7FNGvLaI5tivoCAsxFVaMD
# Node 22540 has attrs:
#   - name : Pony - Extended Mix
#   - type : track
#   - uri : spotify:track:5XO5UiZmVaLFMFs1VaaxT5
# Node 22541 has attrs:
#   - name : Get Ur Freak On
#   - type : track
#   - uri : spotify:track:6zsk6uF3MxfIeHPlubKBvR
# Node 22542 has attrs:
#   - name : Low (feat T-Pain) - Feat T-Pain Album Version
#   - type : track
#   - uri : spotify:track:0CAfXk7DXMnon4gLudAp7J
# Node 22543 has attrs:
#   - name : Hit the Quan - Original Version
#   - type : track
#   - uri : spotify:track:4OjuzM3rTWp3q60mEldNSF
# Node 22544 has attrs:
#   - name : Shake That Monkey
#   - type : track
#   - uri : spotify:track:3XabgBQYC7H80agKcAq83Y
# Node 22545 has attrs:
#   - name : Bugatti
#   - type : track
#   - uri : spotify:track:0uFvvXbmGIXlf5ZgtHyYpf
# Node 22546 has attrs:
#   - name : Ms. New Booty - feat. Ying Yang Twins and Mr. ColliPark
#   - type : track
#   - uri : spotify:track:0k6HUzaRHpQ3eEWr1C7Esh
# Node 22547 has attrs:
#   - name : Back That Azz Up
#   - type : track
#   - uri : spotify:track:6o2g1BJvtYQssH84kBYs7y
# Node 22548 has attrs:
#   - name : Bend Ova
#   - type : track
#   - uri : spotify:track:35x6JdLCr4VWWR5ShNoAWo
# Node 22549 has attrs:
#   - name : Booty
#   - type : track
#   - uri : spotify:track:5pKBCp3tRnM0VmNW4QL08v
# Node 22550 has attrs:
#   - name : How Low
#   - type : track
#   - uri : spotify:track:1WtTLtofvcjQM3sXSMkDdX
# Node 22551 has attrs:
#   - name : Twerk It
#   - type : track
#   - uri : spotify:track:0iVKOcxFG4rGSQDXHwSpVp
# Node 22552 has attrs:
#   - name : 7/11
#   - type : track
#   - uri : spotify:track:02M6vucOvmRfMxTXDUwRXu
# Node 22553 has attrs:
#   - name : Uptown Funk
#   - type : track
#   - uri : spotify:track:32OlwWuMpZ6b0aN2RZOeMS
# Node 22554 has attrs:
#   - name : Bitch Better Have My Money
#   - type : track
#   - uri : spotify:track:5lnsCyEKWofnC00U4Ax0ti
# Node 22555 has attrs:
#   - name : Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack)
#   - type : track
#   - uri : spotify:track:285HeuLxsngjFn4GGegGNm
# Node 22556 has attrs:
#   - name : Sexy Bitch (feat. Akon) - feat. Akon
#   - type : track
#   - uri : spotify:track:77V0TWycxV4wuhcip5LF3X
# Node 22557 has attrs:
#   - name : Billie Jean
#   - type : track
#   - uri : spotify:track:5ChkMS8OtdzJeqyybCc9R5
# Node 22558 has attrs:
#   - name : Party Rock Anthem
#   - type : track
#   - uri : spotify:track:7mitXLIMCflkhZiD34uEQI
# Node 22559 has attrs:
#   - name : Stayin' Alive
#   - type : track
#   - uri : spotify:track:6pyzBTIjcO2AMkKE6x2Otb
# Node 22560 has attrs:
#   - name : Y.M.C.A.
#   - type : track
#   - uri : spotify:track:4YOJFyjqh8eAcbKFfv88mV
# Node 22561 has attrs:
#   - name : Bailando - The Infantry Remix
#   - type : track
#   - uri : spotify:track:5NcDEvhAche4ruS5O4EGUh
# Node 22562 has attrs:
#   - name : Emergency
#   - type : track
#   - uri : spotify:track:6sKAs2tdtTVTO2U0IgJAur
# Node 22563 has attrs:
#   - name : Bang Bang
#   - type : track
#   - uri : spotify:track:3oEekS4xhmFQ88ieCVTZ7H
# Node 22564 has attrs:
#   - name : Muevelo (feat. Wisin)
#   - type : track
#   - uri : spotify:track:5Ra1n0XZPneh64gdF3Jv0g
# Node 22565 has attrs:
#   - name : Bangarang (feat. Sirah)
#   - type : track
#   - uri : spotify:track:3V2cgvvI483DKomiZBYsAA
# Node 22566 has attrs:
#   - name : Bailando - Spanish Version
#   - type : track
#   - uri : spotify:track:32lm3769IRfcnrQV11LO4E
# Node 22567 has attrs:
#   - name : I'm an Albatraoz
#   - type : track
#   - uri : spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# Node 22568 has attrs:
#   - name : Come Get It Bae
#   - type : track
#   - uri : spotify:track:444P4wvSDa0SD5HE4YGx9B
# Node 22569 has attrs:
#   - name : It Takes Two
#   - type : track
#   - uri : spotify:track:0gFB5H3pHN13ERt2FyMuWi
# Node 22570 has attrs:
#   - name : Don't Stop 'Til You Get Enough - Single Version
#   - type : track
#   - uri : spotify:track:46eu3SBuFCXWsPT39Yg3tJ
# Node 22571 has attrs:
#   - name : It's Tricky
#   - type : track
#   - uri : spotify:track:6jBCehpNMkwFVF3dz4nLIW
# Node 22572 has attrs:
#   - name : Turn Down for What
#   - type : track
#   - uri : spotify:track:67awxiNHNyjMXhVgsHuIrs
# Node 22573 has attrs:
#   - name : Yeah!
#   - type : track
#   - uri : spotify:track:0XUfyU2QviPAs6bxSpXYG4
# Node 22574 has attrs:
#   - name : Work It
#   - type : track
#   - uri : spotify:track:3jagJCUbdqhDSPuxP8cAqF
# Node 22575 has attrs:
#   - name : Tumba La Casa (Remix) [feat. Daddy Yankee, Nicky Jam, Farruko, Arcangel, De La Ghetto, Zion & Ñengo Flow]
#   - type : track
#   - uri : spotify:track:6n5hSi8Mdyee0XvsmIffeV
# Node 22576 has attrs:
#   - name : Tremenda Sata (Remix) [feat. Daddy Yankee, Nicky Jam, Arcangel, De La Ghetto & Plan B]
#   - type : track
#   - uri : spotify:track:6FFUyFocgvYlHQVjuMKX0p
# Node 22577 has attrs:
#   - name : Do It Like Me
#   - type : track
#   - uri : spotify:track:0z9hbAY5d0RhmvZr3DWMPK
# Node 22578 has attrs:
#   - name : Freedom! '90 - Remastered
#   - type : track
#   - uri : spotify:track:3tyTt5pEWblt96j1HsXiV5
# Node 22579 has attrs:
#   - name : Happy - From "Despicable Me 2"
#   - type : track
#   - uri : spotify:track:5b88tNINg4Q4nrRbrCXUmg
# Node 22580 has attrs:
#   - name : Are You In?
#   - type : track
#   - uri : spotify:track:0IRvfvDUVIvbvgCDY17wnp
# Node 22581 has attrs:
#   - name : Bang Bang
#   - type : track
#   - uri : spotify:track:3oEekS4xhmFQ88ieCVTZ7H
# Node 22582 has attrs:
#   - name : Toca
#   - type : track
#   - uri : spotify:track:1qm9MfTAoEixNPSqshHqfV
# Node 22583 has attrs:
#   - name : Toma
#   - type : track
#   - uri : spotify:track:7dFgljcBj9CPDrUQD9LbiP
# Node 22584 has attrs:
#   - name : Heaven
#   - type : track
#   - uri : spotify:track:71MFFmfNghNbW8n2cYVan3
# Node 22585 has attrs:
#   - name : Once Bitten Twice Shy
#   - type : track
#   - uri : spotify:track:7pkWZL0kA26s754CwyK0SH
# Node 22586 has attrs:
#   - name : Be Good to Yourself
#   - type : track
#   - uri : spotify:track:2D5xQtVNi4o6F3Gh1qxD3Y
# Node 22587 has attrs:
#   - name : Born In The U.S.A.
#   - type : track
#   - uri : spotify:track:310epXrlbXmfGcD1qSdgVV
# Node 22588 has attrs:
#   - name : I'll Be There For You
#   - type : track
#   - uri : spotify:track:0wqxdcJoEYmDzQEykl7mU1
# Node 22589 has attrs:
#   - name : Your Love
#   - type : track
#   - uri : spotify:track:4oDZ5L8izBals6jKBJDBcX
# Node 22590 has attrs:
#   - name : I Don't Want to Miss a Thing - From the Touchstone film, "Armageddon"
#   - type : track
#   - uri : spotify:track:0c1gHntWjKD7QShC8s99sq
# Node 22591 has attrs:
#   - name : Right Here Waiting
#   - type : track
#   - uri : spotify:track:4LFwNJWoj74Yd71fIr1W8x
# Node 22592 has attrs:
#   - name : When I See You Smile
#   - type : track
#   - uri : spotify:track:0tKjVEJlX3IZ5L1rEJc5hh
# Node 22593 has attrs:
#   - name : Listen To Your Heart
#   - type : track
#   - uri : spotify:track:78TnMTAFmWUWWCgNXR7D3K
# Node 22594 has attrs:
#   - name : Unskinny Bop - 2006 - Remaster
#   - type : track
#   - uri : spotify:track:1Z6lKdYhwp8WYoBqGCKxlM
# Node 22595 has attrs:
#   - name : Heaven
#   - type : track
#   - uri : spotify:track:3wgzAliQocAzmpi5dEwRqJ
# Node 22596 has attrs:
#   - name : Jump - 2015 Remastered Version
#   - type : track
#   - uri : spotify:track:7N3PAbqfTjSEU1edb2tY8j
# Node 22597 has attrs:
#   - name : Lost In Your Eyes
#   - type : track
#   - uri : spotify:track:6PMDILZiYo4YzMBbE0dGK9
# Node 22598 has attrs:
#   - name : Sister Christian
#   - type : track
#   - uri : spotify:track:57trQKFZdJxHia4sMJioWk
# Node 22599 has attrs:
#   - name : Patience
#   - type : track
#   - uri : spotify:track:7D5n2kpYH2WSqIyEO9MeXf
# Node 22600 has attrs:
#   - name : All Night Long (All Night) - Single Version
#   - type : track
#   - uri : spotify:track:2Wb9ejnmy27DUTUe9YF5Ew
# Node 22601 has attrs:
#   - name : Straight Up
#   - type : track
#   - uri : spotify:track:5xl5582IihbEZAnfj0xyso
# Node 22602 has attrs:
#   - name : Can't Fight This Feeling
#   - type : track
#   - uri : spotify:track:5WwqdeavrQrbeAMDxGawse
# Node 22603 has attrs:
#   - name : Love Come Down (12" Version) - Remastered
#   - type : track
#   - uri : spotify:track:0cQ12DEpXmnoxKDXtdYEW7
# Node 22604 has attrs:
#   - name : Once Bitten Twice Shy
#   - type : track
#   - uri : spotify:track:7pkWZL0kA26s754CwyK0SH
# Node 22605 has attrs:
#   - name : Wanted Dead Or Alive
#   - type : track
#   - uri : spotify:track:2fY6tqgrlrg1ky9fgs0t5u
# Node 22606 has attrs:
#   - name : Open Arms
#   - type : track
#   - uri : spotify:track:2w4EpqGasrz9qdTwocx54t
# Node 22607 has attrs:
#   - name : Love Is A Battlefield
#   - type : track
#   - uri : spotify:track:06dAFXkgM2OGAkGS3CxpEm
# Node 22608 has attrs:
#   - name : Endless Summer Nights
#   - type : track
#   - uri : spotify:track:2iXH35MhsqO5Ry8a7iptpJ
# Node 22609 has attrs:
#   - name : Round and Round
#   - type : track
#   - uri : spotify:track:5B6Z7NwVqA7W3UFiqBdEJC
# Node 22610 has attrs:
#   - name : Here I Go Again
#   - type : track
#   - uri : spotify:track:567EwOGPAXg7Y9DQZTEFEE
# Node 22611 has attrs:
#   - name : Take Me Home Tonight
#   - type : track
#   - uri : spotify:track:7b4yGtR0rujvLi5EBfKKJ2
# Node 22612 has attrs:
#   - name : Lovin', Touchin', Squeezin'
#   - type : track
#   - uri : spotify:track:0VQ0n5gMgJLNixG8BfWBT5
# Node 22613 has attrs:
#   - name : (I've Had) The Time of My Life
#   - type : track
#   - uri : spotify:track:4BFMQ15vXr626UOoZL8bUI
# Node 22614 has attrs:
#   - name : Heaven
#   - type : track
#   - uri : spotify:track:71MFFmfNghNbW8n2cYVan3
# Node 22615 has attrs:
#   - name : Once Bitten Twice Shy
#   - type : track
#   - uri : spotify:track:7pkWZL0kA26s754CwyK0SH
# Node 22616 has attrs:
#   - name : Be Good to Yourself
#   - type : track
#   - uri : spotify:track:2D5xQtVNi4o6F3Gh1qxD3Y
# Node 22617 has attrs:
#   - name : Born In The U.S.A.
#   - type : track
#   - uri : spotify:track:310epXrlbXmfGcD1qSdgVV
# Node 22618 has attrs:
#   - name : I'll Be There For You
#   - type : track
#   - uri : spotify:track:0wqxdcJoEYmDzQEykl7mU1
# Node 22619 has attrs:
#   - name : Your Love
#   - type : track
#   - uri : spotify:track:4oDZ5L8izBals6jKBJDBcX
# Node 22620 has attrs:
#   - name : I Don't Want to Miss a Thing - From the Touchstone film, "Armageddon"
#   - type : track
#   - uri : spotify:track:0c1gHntWjKD7QShC8s99sq
# Node 22621 has attrs:
#   - name : Right Here Waiting
#   - type : track
#   - uri : spotify:track:4LFwNJWoj74Yd71fIr1W8x
# Node 22622 has attrs:
#   - name : When I See You Smile
#   - type : track
#   - uri : spotify:track:0tKjVEJlX3IZ5L1rEJc5hh
# Node 22623 has attrs:
#   - name : Listen To Your Heart
#   - type : track
#   - uri : spotify:track:78TnMTAFmWUWWCgNXR7D3K
# Node 22624 has attrs:
#   - name : Unskinny Bop - 2006 - Remaster
#   - type : track
#   - uri : spotify:track:1Z6lKdYhwp8WYoBqGCKxlM
# Node 22625 has attrs:
#   - name : Heaven
#   - type : track
#   - uri : spotify:track:3wgzAliQocAzmpi5dEwRqJ
# Node 22626 has attrs:
#   - name : Jump - 2015 Remastered Version
#   - type : track
#   - uri : spotify:track:7N3PAbqfTjSEU1edb2tY8j
# Node 22627 has attrs:
#   - name : Lost In Your Eyes
#   - type : track
#   - uri : spotify:track:6PMDILZiYo4YzMBbE0dGK9
# Node 22628 has attrs:
#   - name : Sister Christian
#   - type : track
#   - uri : spotify:track:57trQKFZdJxHia4sMJioWk
# Node 22629 has attrs:
#   - name : Patience
#   - type : track
#   - uri : spotify:track:7D5n2kpYH2WSqIyEO9MeXf
# Node 22630 has attrs:
#   - name : All Night Long (All Night) - Single Version
#   - type : track
#   - uri : spotify:track:2Wb9ejnmy27DUTUe9YF5Ew
# Node 22631 has attrs:
#   - name : Straight Up
#   - type : track
#   - uri : spotify:track:5xl5582IihbEZAnfj0xyso
# Node 22632 has attrs:
#   - name : Can't Fight This Feeling
#   - type : track
#   - uri : spotify:track:5WwqdeavrQrbeAMDxGawse
# Node 22633 has attrs:
#   - name : Love Come Down (12" Version) - Remastered
#   - type : track
#   - uri : spotify:track:0cQ12DEpXmnoxKDXtdYEW7
# Node 22634 has attrs:
#   - name : Once Bitten Twice Shy
#   - type : track
#   - uri : spotify:track:7pkWZL0kA26s754CwyK0SH
# Node 22635 has attrs:
#   - name : Wanted Dead Or Alive
#   - type : track
#   - uri : spotify:track:2fY6tqgrlrg1ky9fgs0t5u
# Node 22636 has attrs:
#   - name : Open Arms
#   - type : track
#   - uri : spotify:track:2w4EpqGasrz9qdTwocx54t
# Node 22637 has attrs:
#   - name : Love Is A Battlefield
#   - type : track
#   - uri : spotify:track:06dAFXkgM2OGAkGS3CxpEm
# Node 22638 has attrs:
#   - name : Endless Summer Nights
#   - type : track
#   - uri : spotify:track:2iXH35MhsqO5Ry8a7iptpJ
# Node 22639 has attrs:
#   - name : Round and Round
#   - type : track
#   - uri : spotify:track:5B6Z7NwVqA7W3UFiqBdEJC
# Node 22640 has attrs:
#   - name : Here I Go Again
#   - type : track
#   - uri : spotify:track:567EwOGPAXg7Y9DQZTEFEE
# Node 22641 has attrs:
#   - name : Take Me Home Tonight
#   - type : track
#   - uri : spotify:track:7b4yGtR0rujvLi5EBfKKJ2
# Node 22642 has attrs:
#   - name : Lovin', Touchin', Squeezin'
#   - type : track
#   - uri : spotify:track:0VQ0n5gMgJLNixG8BfWBT5
# Node 22643 has attrs:
#   - name : (I've Had) The Time of My Life
#   - type : track
#   - uri : spotify:track:4BFMQ15vXr626UOoZL8bUI
# Node 22644 has attrs:
#   - name : Oh Sherrie
#   - type : track
#   - uri : spotify:track:6igXYiQIuXwjO9myYFqSrj
# Node 22645 has attrs:
#   - name : The Promise
#   - type : track
#   - uri : spotify:track:48p5E25cFPanxuwCTmTpuL
# Node 22646 has attrs:
#   - name : Take It On the Run - Remastered
#   - type : track
#   - uri : spotify:track:5gys5nzVQIYhgHIfiOJYva
# Node 22647 has attrs:
#   - name : Here I Go Again
#   - type : track
#   - uri : spotify:track:567EwOGPAXg7Y9DQZTEFEE
# Node 22648 has attrs:
#   - name : Crush On You
#   - type : track
#   - uri : spotify:track:2sYLlZU3FuCF8SKNeIvdKA
# Node 22649 has attrs:
#   - name : Take Me Home Tonight
#   - type : track
#   - uri : spotify:track:7b4yGtR0rujvLi5EBfKKJ2
# Node 22650 has attrs:
#   - name : You Got It (The Right Stuff)
#   - type : track
#   - uri : spotify:track:4buDeg67vos7KP1yHrS9wl
# Node 22651 has attrs:
#   - name : Rock Of Ages (2012)
#   - type : track
#   - uri : spotify:track:0zOUO2Cbz0C1F8qbrebIxn
# Node 22652 has attrs:
#   - name : Hard To Say I'M Sorry / Get Away
#   - type : track
#   - uri : spotify:track:07TnWCHrFkvF61GzJuLVt0
# Node 22653 has attrs:
#   - name : Jessie's Girl
#   - type : track
#   - uri : spotify:track:5RsUlxLto4NZbhJpqJbHfN
# Node 22654 has attrs:
#   - name : Don't Know What You Got (Till It's Gone)
#   - type : track
#   - uri : spotify:track:3vPrFUtWpKT9oNW94NDDEW
# Node 22655 has attrs:
#   - name : I Can't Drive 55
#   - type : track
#   - uri : spotify:track:1MqGKtY9L5qjPi8s7gX645
# Node 22656 has attrs:
#   - name : Billie Jean
#   - type : track
#   - uri : spotify:track:5ChkMS8OtdzJeqyybCc9R5
# Node 22657 has attrs:
#   - name : Dreams
#   - type : track
#   - uri : spotify:track:2APxH5XbOLDTmW9X5yi6Hw
# Node 22658 has attrs:
#   - name : Push It
#   - type : track
#   - uri : spotify:track:0TT7wJiEYD5GAeJfSR1ETX
# Node 22659 has attrs:
#   - name : Party Girls
#   - type : track
#   - uri : spotify:track:1qKBxhoa2DOiLw1dulStDT
# Node 22660 has attrs:
#   - name : Don't Wait
#   - type : track
#   - uri : spotify:track:5sBdbAZ2a2LJ775CsbkM2h
# Node 22661 has attrs:
#   - name : Fishin' In The Dark
#   - type : track
#   - uri : spotify:track:7lJbTVbDEMa3w7NFamrwdq
# Node 22662 has attrs:
#   - name : Highway to Hell
#   - type : track
#   - uri : spotify:track:2zYzyRzz6pRmhPzyfMEC8s
# Node 22663 has attrs:
#   - name : Dream On
#   - type : track
#   - uri : spotify:track:5MxNLUsfh7uzROypsoO5qe
# Node 22664 has attrs:
#   - name : Back In Black
#   - type : track
#   - uri : spotify:track:08mG3Y1vljYA6bvDt4Wqkj
# Node 22665 has attrs:
#   - name : Sweet Home Alabama
#   - type : track
#   - uri : spotify:track:4CJVkjo5WpmUAKp3R44LNb
# Node 22666 has attrs:
#   - name : Jessie's Girl
#   - type : track
#   - uri : spotify:track:5RsUlxLto4NZbhJpqJbHfN
# Node 22667 has attrs:
#   - name : I Want You to Want Me
#   - type : track
#   - uri : spotify:track:1JkZg3eMQTmTn93E8Yd3UL
# Node 22668 has attrs:
#   - name : Take Me Home Tonight
#   -
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
a,b,c = pl2graph(0, sample_playlist)

# %%
a[0]

# %%
a[1]

# %%
a[2]

# %%
G = nx.Graph()
G.add_nodes_from(a)

# %%
G.nodes['pl_0']

# %%
g = gt.Graph()

node_attrs = {'name': 'node1', 'color': 'red', 'size':10}
v = g.add_vertex()
g.vp['name'] = g.new_vertex_property('string')
g.vp['color'] = g.new_vertex_property('string')
g.vp['size'] = g.new_vertex_property('int')
for key, value in node_attrs.items():
    g.vp[key][v] = value
